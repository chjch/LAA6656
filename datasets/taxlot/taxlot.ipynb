# %%
import geopandas as gpd
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')

# %%
taxlot = r"D:\OneDrive - University of Florida\Research\FIBER Postdoc\LAA 6656 studio\Spring 2020\DataFiles\taxlot.dbf"

# %%
taxlot_gdf = gpd.read_file(taxlot)
taxlot_df = pd.DataFrame(taxlot_gdf.drop(columns='geometry'))

# %%
taxlot_df['JV'].max()
# Out:
# 42833859

# %%
taxlot_sf = taxlot_df.loc[taxlot_gdf['DORUC']=='001']
taxlot_sf['JV'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
taxlot_sf[taxlot_sf['ACRES']<0.4]['ACRES'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
taxlot_sf.loc[taxlot_sf['ACRES']<0.5].plot.scatter(x='ACRES', y='JV')
# Out:
# <AxesSubplot:xlabel='ACRES', ylabel='JV'>
